# %%
include("Futbolista.jl")
using .Futbolista: Plotter, DataLoaders

const sb = DataLoaders.StatsbombLoader
const pm = Plotter.Passmap.plot_passmap

loader = sb.SBLoader("local", raw"C:\repository\open-data\data");

# %%
events_df = sb.load_events(loader, 7298)
p = pm(events_df, "home", "mean")
